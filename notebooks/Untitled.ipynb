# %%
import os

# Go up one level from notebooks to Churn Prediction folder
os.chdir('..')

print("Current directory:", os.getcwd())
# Should show: C:\Users\navya\OneDrive\Desktop\Churn Prediction

print("\nFiles in this folder:")
for item in os.listdir('.'):
    print(f"  {item}")
# Out:
# Current directory: C:\Users\navya\OneDrive\Desktop\Churn Prediction
#
# Files in this folder:
#   notebooks
#   output
#   requirements.txt
#   screenshots

# %%
gitignore = """# Data files
data/
*.db

# Large prediction files
output/churn_predictions.csv
output/churn_predictions_500k.csv
output/churn_predictions_500k.xlsx
output/churn_predictions.xlsx

# Model files
models/
*.pkl

# Virtual environment
venv/
__pycache__/
*.pyc
.ipynb_checkpoints/

# Dashboard
dashboard/*.pbix

# Environment
.env
*.env
"""

with open('.gitignore', 'w') as f:
    f.write(gitignore)

print(".gitignore created.")
# Out:
# .gitignore created.

# %%
requirements = """pandas==2.3.3
numpy==2.3.5
scikit-learn==1.7.2
xgboost==3.2.0
matplotlib==3.10.6
seaborn==0.13.2
shap
sqlalchemy==2.0.43
openpyxl
imbalanced-learn==0.14.0
joblib==1.5.2
jupyter
"""

with open('requirements.txt', 'w') as f:
    f.write(requirements)

print("requirements.txt created.")
# Out:
# requirements.txt created.

# %%
import os

print("Current directory:", os.getcwd())
print()

files_to_check = ['.gitignore', 'requirements.txt', 'README.md']
for f in files_to_check:
    if os.path.exists(f):
        size = os.path.getsize(f) / 1024
        print(f"  ✅ {f} — {size:.1f} KB")
    else:
        print(f"  ❌ {f} — NOT FOUND")

print("\nAll files in Churn Prediction folder:")
for item in sorted(os.listdir('.')):
    print(f"  {item}")
# Out:
# Current directory: C:\Users\navya\OneDrive\Desktop\Churn Prediction
#
#   ✅ .gitignore — 0.3 KB
#   ✅ requirements.txt — 0.2 KB
#   ❌ README.md — NOT FOUND
#
# All files in Churn Prediction folder:
#   .gitignore
#   notebooks
#   output
#   requirements.txt
#   screenshots
